# %%
import pandas as pd

results_text = pd.read_csv('text.csv', ';')
results_key = pd.read_csv('key.csv', ';')

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_graph(data_frame, x_name, y_name, plot_name):
    x = data_frame[x_name]
    y = [float(num.replace(',', '.')) for num in data_frame[y_name]]
    plt.plot(x, y, 'g', marker='o', linestyle='dashed')
    plt.show()

# %%
results_key_250 = results_key[0 : 20]
plot_graph(results_key_250, 'KeyLength', 'Probability', 'Key 250')

# %%
results_key_500 = results_key[20 : 40]
plot_graph(results_key_500, 'KeyLength', 'Probability', 'Key 500')

# %%
results_key_1000 = results_key[40 : 80]
plot_graph(results_key_1000, 'KeyLength', 'Probability', 'Key 1000')

# %%
results_key_2000 = results_key[80 : 120]
plot_graph(results_key_2000, 'KeyLength', 'Probability', 'Key 2000')

# %%
results_text_4 = results_text[0 : 12]
plot_graph(results_text_4, 'TextLength', 'Probability', 'Text 4')

# %%
results_text_8 = results_text[12 : 24]
plot_graph(results_text_8, 'TextLength', 'Probability', 'Text 8')

# %%
results_text_12 = results_text[24 : 36]
plot_graph(results_text_12, 'TextLength', 'Probability', 'Text 12')

# %%
results_text_16 = results_text[36 : 48]
plot_graph(results_text_16, 'TextLength', 'Probability', 'Text 16')

# %%
results_text_20 = results_text[48 : 60]
plot_graph(results_text_20, 'TextLength', 'Probability', 'Text 20')
